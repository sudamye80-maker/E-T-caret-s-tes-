# %%
    class Ürün () :
        def __init__(self, isim,  fiyat, stok_miktarı, kategori):
            
            self.isim = isim
            self.fiyat = fiyat
            self.stok_miktarı = kategori
            self.satıs_sayısı = 0
            print(f"ürün eklendi: {isim}")
        def bilgi_goster(self):
            stok_durumu = "stokta var" if self.stok_miktarı > 0 else "stokta yok"
            print(f"\n {self.isim}")
            print(f"stok : {self.stok_miktarı}")
            print(f"kategori : {self.kategori}")
            print(f"satıs : {self.satıs_sayısı}")
            print(f"durum :  {stok_durumu}")

        def fiyat_güncelle(self,yeni_fiyat):
                eski_fiyat = self.fiyat
                self.fiyat = yeni_fiyat
                print(f"{self.isim} fiyat güncellendi : {eski_fiyat} TL --> {yeni_fiyat} TL")
                def stok_ekle(self_miktar):
                    self.stok_miktarı += self.miktar
                    print(f"{self.isim} stok artırıldı + {miktar} adet (Toplam{self.stok_miktarı}")
                    
        def satıs_yap(self, miktar):
            
            if self.stok_miktarı >= miktar:
                self.stok_miktarı -= miktar:
                self.satıs_sayısı += miktar:
                toplam_gelir = miktar * self.fiyat
                print(f"{miktar} adet{self.isim} satıldı. gelir : {toplam_gelir} TL")
                print(f" Kalan stok: {self.stok_miktarı} adet")
                return toplam_gelir
            else:
                print(f"Yetersiz stok!!!istenen miktar{miktar}")
                mevcut: ({self.stok_miktarı} "adet")
                return 0
        def indirim_uygula(self,indirim):
                    eski_fiyat = self.fiyat
                    self.fiyat = self.fiyat * (100-indirim/100)  
                    print(f"{indirim uygulandı}")
                    print(f"{eski_fiyat}TL =--> {self.fiyat} TL")
# Out:
#   Cell In[9], line 28
#     self.stok_miktarı -= miktar:
#                                ^
# SyntaxError: invalid syntax

# %%
laptop = Ürün("Gaming laptop", 6500, 30, "elektronik")
kulaklık = Ürün("Bluetooth kulaklık", 5000, 200, "Elektronik")
mause = Ürün("Oyun mause", 3000, 2500, "Elektronik")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 laptop = Ürün("Gaming laptop", 6500, 30, "elektronik")
#       2 kulaklık = Ürün("Bluetooth kulaklık", 5000, 200, "Elektronik")
#       3 mause = Ürün("Oyun mause", 3000, 2500, "Elektronik")
#
# NameError: name 'Ürün' is not defined

# %%
laptop.bilgi_göster()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 laptop.bilgi_göster()
#
# NameError: name 'laptop' is not defined
