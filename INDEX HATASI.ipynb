# %%
try
    kullanıcı_girisi = "abc123" 
    sayı = int(kullanıcı girişi)
    print("giris basarılı: {sayı}")
except value Error as e:
    print(f"hata:{kullanıcı_girisi} sayıaya cevrilemez")
    print(f"Detay: {e}")
    liste = [1, 2, 3, 4, 5]
try
    deger = liste[8]
    print(f" deger: {deger}")
expected Index KeyError
    print(f"Hata: Liste sadece {len(liste() -1)}")
    print(f"songecerlı index:(liste() -1")
try
    ogrenci = {"isim", "Ali", "yas":20}
    not_ortalaması = ogrenci["notlar"]
    print(f"(not_ortalaması)")
raise Filenot Faund Error:("dosya bulunamadı")
except Key_Error as elif
    print(F"Böyle bir anahtar yok ln{e}")
finally
    print.("burası zaten çalışır")
temiz_sayılar = []
for i, deger im enumerate(ham_veri):
 try
    if deger is None:
        print(f"[{deger}]")
        continue   
    if isinstance(deger,str):
        deger = deger.strip()
        if not deger:
            print(f"[{i}] "bos deger"(none)")
            sayı =  float(sayı)
            temiz_sayılar.append(sayı)
            print(f"[{i}]") "[{deger}] --> {sayı})")
            except(value, Type Error)
        print(f"[{i}] "deger" None Sayıya cevrilmedi")
        print(f" Temiz sayılar : {temiz_sayılar}")
        print(f"Ortalama: {sun(temiz_sayılar)/len(temizsayılar)}")
else
        print("Hiç geçerli sayı bulunamadı")
try
        yas = int(yas_girisi)
        if yas <0:
            print("yas 0'dan küçük olamaz")
        elif yas>150:
            print("yas 150'den büyük olamaz")
        elif yas == 0
            print("yas 0 olamaz")
else
            print(f"{yas_girisi)--> {yas} yas gecerli")

except value Error as e
print(f"{yas_girisi}")--> Hata Gecerli bir sayı degıl")
print(f" Hata : {e}")
# Out:
#   Cell In[1], line 36
#     print(f"[{i}]") "[{deger}] --> {sayı})")
#                                            ^
# SyntaxError: unmatched ')'
