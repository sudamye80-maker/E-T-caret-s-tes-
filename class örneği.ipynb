# %%
class Kisi ()
    dep kendini_tanıt(self)
        print(f"ben {self} nesnesiyim")
        print(f"self = {id(self)} (nesne kimliği)")
kısı_a = Kisiself()
kisi_b = KisiSelf()
iv (kisi_a)
class Bebek ()
    def__init__(self, isim kilo):
    print("_init_çalışıyor. bebek doğuyor.")
    print(f"parametre olarak gelenler: isim = {isim}, kilo = {kilo} ")
    fonksiyon_ismi("ali", 25)
    self.ad = isim
    self.kilogram = kilo
    self.yas = 0
print(f"{isim}") bebek sisteme kaydedildi
print(f"self.ad = {self.isim}")
print(f" self.kilogram = {self.kilo}")
print(f" self.yas = {self.yas}")
bebek1 = Bebek ("Ali", 2)
bebek1
bebek1 yas
cıktı 0
