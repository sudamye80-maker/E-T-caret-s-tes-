# %%
def kısı_oluştur(isim, ** özellikler):
    kısı =  {"kısı": isim}
    kısı.update(özellikler)
    print("kisi oluşturuldu")
    print(f" isim:  {kısı ["isim"]}")
    if"yas" in kisi 
     print(f"yas = "{kisi["isim"]}")
           if"meslek" in kisi
           print(f" meslek: {["meslek"]}")
           diger_özellikler = (k : x fark, v in kisi.items())
           if k not in["isim","yas","meslek", "sehir", "telefon", "email"]
           if deger_özelikleri
           print(f"diger özellikler: (diger_özellikler)")
           return kisi
           kisi1 = kisi _olustur()
           sehir = "ankara", telefon = 52365, "email = ad@soyad.com"
           int_sayılar = list(map)int,(string sayılar)int_sayılar
           [10, 20, 30, 40 ]
           int_sayılar(10, 20, 30, 40)
           str_sayılar = list(map(str, int_sayılar1))
           [10, 20, 30, 40]
           büyük_kelimeler = list(map(str.upper,{}, p_dilleri))
            büyük kelimeler
            adlar 1 = ["ali", "kemal", "ahmet"]
            soyad" = "öz", "yılmaz"]
            birleşik = list(zip(adlar",soyadlar 1 ))
             sayılar =  [1, 2, 3, 4, 5, 6]
             büyük_var = any(x>5 for x in sayılar) 
             büyük_var
             hepsi_büyük = all(x>7  for x in sayılar)
             hepsi_büyük
             False
